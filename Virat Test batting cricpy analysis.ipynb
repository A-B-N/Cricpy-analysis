# %%
import cricpy.analytics as ca
import warnings
warnings.filterwarnings(action="ignore")

# %%
ca.getPlayerData(253802,dir="..",file="kohli.csv")
# Out:
#      Runs Mins   BF  4s 6s     SR Pos Dismissal Inns      Opposition  \
# 0       4   13   10   1  0  40.00   5    caught    1   v West Indies
# 1      15   72   54   2  0  27.77   5    caught    3   v West Indies
# 2       0    1    2   0  0   0.00   5    caught    1   v West Indies
# 3      27  118  107   1  1  25.23   5    caught    3   v West Indies
# 4      30   62   53   2  0  56.60   5    caught    2   v West Indies
# 5     DNB    -    -   -  -      -   -         -    4   v West Indies
# 6      52  154  111   5  0  46.84   6    caught    2   v West Indies
# 7      63  136  114   3  1  55.26   6    caught    4   v West Indies
# 8      11   28   21   1  0  52.38   7    caught    2     v Australia
# 9       0    3    1   0  0   0.00   6       lbw    4     v Australia
# 10     23   50   41   3  0  56.09   6    caught    1     v Australia
# 11      9   35   24   2  0  37.50   6       lbw    3     v Australia
# 12     44  107   81   6  0  54.32   6    caught    1     v Australia
# 13     75  191  136   9  0  55.14   6    caught    3     v Australia
# 14    116  237  213  11  1  54.46   6       lbw    2     v Australia
# 15     22   96   62   2  0  35.48   6   run out    4     v Australia
# 16     58  143  107   8  0  54.20   5    caught    1   v New Zealand
# 17    103  284  193  14  1  53.36   5       lbw    2   v New Zealand
# 18    51*  130   82   9  0  62.19   5   not out    4   v New Zealand
# 19     19   70   67   3  0  28.35   5    bowled    1       v England
# 20    14*   17   21   3  0  66.66   3   not out    4       v England
# 21     19   65   55   3  0  34.54   5    caught    1       v England
# 22      7   16   13   1  0  53.84   5    caught    3       v England
# 23      6   31   24   1  0  25.00   5    caught    1       v England
# 24     20   86   60   3  0  33.33   5    caught    3       v England
# 25    103  356  295  11  0  34.91   5       lbw    2       v England
# 26    107  266  206  15  1  51.94   5    caught    2     v Australia
# 27    DNB    -    -   -  -      -   -         -    4     v Australia
# 28     34  119   92   3  0  36.95   5    caught    2     v Australia
# 29    67*  157  129   7  1  51.93   5   not out    2     v Australia
# ..    ...  ...  ...  .. ..    ...  ..       ...  ...             ...
# 106  104*  208  119  12  2  87.39   4   not out    3     v Sri Lanka
# 107   213  386  267  17  2  79.77   4    caught    2     v Sri Lanka
# 108   243  447  287  25  0  84.66   4       lbw    1     v Sri Lanka
# 109    50   89   58   3  0  86.20   5    caught    3     v Sri Lanka
# 110     5   14   13   0  0  38.46   4    caught    2  v South Africa
# 111    28   62   40   4  0  70.00   4       lbw    4  v South Africa
# 112   153  379  217  15  0  70.50   4    caught    2  v South Africa
# 113     5   22   20   1  0  25.00   4       lbw    4  v South Africa
# 114    54  146  106   9  0  50.94   4    caught    1  v South Africa
# 115    41  131   79   6  0  51.89   5    bowled    3  v South Africa
# 116   149  277  225  22  1  66.22   4    caught    2       v England
# 117    51  185   93   4  0  54.83   4       lbw    4       v England
# 118    23   73   57   2  0  40.35   4    caught    1       v England
# 119    17   57   29   2  0  58.62   5    caught    3       v England
rows x 12 columns]

# %%
import matplotlib.pyplot as plt
ca.batsmanRunsFreqPerf("../kohli.csv","Virat Kohli")

# %%
ca.batsmanMeanStrikeRate("../kohli.csv","Virat Kohli")

# %%
ca.batsmanRunsRanges("../kohli.csv","Virat Kohli")

# %%
ca.batsman6s("../kohli.csv","Virat Kohli")

# %%
ca.batsmanDismissals("../kohli.csv","Virat Kohli")

# %%
ca.battingPerf3d("../kohli.csv","Virat Kohli")

# %%
ca.batsmanAvgRunsGround("../kohli.csv","Virat Kohli")

# %%
ca.batsmanAvgRunsOpposition("../kohli.csv","Virat Kohli")

# %% [markdown]
# The plot below shows the Runs Likelihood for a batsman. For this the performance of Kohli is plotted as a 3D scatter plot with Runs versus Balls Faced + Minutes at crease. This function uses K-Means clustering where the centroids of the three clusters are computed and plotted.

# %%
ca.batsmanRunsLikelihood("../kohli.csv","Virat Kohli")

# %%
ca.batsmanPerfBoxHist("../kohli.csv","Virat Kohli")

# %%
kohlisp = ca.getPlayerDataSp(253802,tdir=".",tfile="kohlisp.csv",ttype="batting")

# %%
ca.batsmanContributionWonLost("./kohlisp.csv","Virat Kohli")

# %%
ca.batsmanPerfHomeAway("./kohlisp.csv","Virat Kohli")

# %%
ca.batsmanCumulativeAverageRuns("./kohlisp.csv","Virat Kohli")

# %%
ca.batsmanCumulativeStrikeRate("../kohli.csv","Virat Kohli")

# %%
ca.batsmanPerfForecast("../kohli.csv","Virat Kohli")
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                 D.runs   No. Observations:                  129
# Model:                 ARIMA(5, 1, 0)   Log Likelihood                -708.770
# Method:                       css-mle   S.D. of innovations             58.657
# Date:                Sun, 23 Jun 2019   AIC                           1431.539
# Time:                        15:38:31   BIC                           1451.558
# Sample:                             1   HQIC                          1439.673
#
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.2567      1.676      0.153      0.879      -3.029       3.543
# ar.L1.D.runs    -0.7145      0.088     -8.146      0.000      -0.886      -0.543
# ar.L2.D.runs    -0.5222      0.106     -4.947      0.000      -0.729      -0.315
# ar.L3.D.runs    -0.5341      0.104     -5.116      0.000      -0.739      -0.329
# ar.L4.D.runs    -0.2600      0.105     -2.478      0.015      -0.466      -0.054
# ar.L5.D.runs    -0.0876      0.088     -1.000      0.319      -0.259       0.084
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.4651           -1.2498j            1.3335           -0.1933
# AR.2            0.4651           +1.2498j            1.3335            0.1933
# AR.3           -1.4661           -0.0000j            1.4661           -0.5000
# AR.4           -1.2165           -1.7029j            2.0928           -0.3487
# AR.5           -1.2165           +1.7029j            2.0928            0.3487
# -----------------------------------------------------------------------------
#                 0
# count  129.000000
# mean     0.158823
# std     58.895750
# min   -121.569557
# 25%    -38.633800
# 50%    -10.305553
# 75%     30.012327
# max    192.416836
